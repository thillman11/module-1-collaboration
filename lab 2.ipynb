# %%
while True:
    last_name = input("Enter student's last name(OR zzz TO QUIT)")
    if last_name == "ZZZ":
        print('Program ended.')
        break
    first_name = input("Enter student's first name")
    GPA = float(input("Enter students GPA"))
    if GPA >= 3.5:
        print(f"{first_name} {last_name} made the deans list")
    elif GPA >= 3.25:
        print(f"{first_name} {last_name} made the honor roll")
    else:
        print(f"{first_name} {last_name} did not qualify")

    print()
# Out:
# Enter student's last name(OR zzz TO QUIT) doe
# Enter student's first name john
# Enter students GPA 3.6
# john doe made the deans list
# Enter student's last name(OR zzz TO QUIT) trent
# Enter student's first name trent
# Enter students GPA 2.6
# trent trent did not qualify
# Enter student's last name(OR zzz TO QUIT) monroe
# Enter student's first name diana
# Enter students GPA 3.3
# diana monroe made the honor roll
# Enter student's last name(OR zzz TO QUIT) hillman
# Enter student's first name tyler
# Enter students GPA 3.9
# tyler hillman made the deans list
# Enter student's last name(OR zzz TO QUIT) white
# Enter student's first name jen
# Enter students GPA 3.1
# jen white did not qualify
# Enter student's last name(OR zzz TO QUIT) ZZZ
# Program ended.
